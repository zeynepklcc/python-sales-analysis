# %%
sınıf_mevcudu=int(input("Toplam Öğrenci Sayısını Giriniz: "))



vize_notları=[]
final_notları=[]
ortalama_notlar=[]
harf_notları=[]


i=1

while i<=sınıf_mevcudu:
    Öğrenci_Ad_Soyad=str(input("Öğrenci Adı ve Soyadını Giriniz: "))
    Öğrenci_Numarası=int(input("Öğrenci Numarasını Giriniz: "))
    vize_notu=int(input(f"{Öğrenci_Ad_Soyad}'ın Vize Notunu Giriniz: "))
    if vize_notu>100 or vize_notu<0:
        print("Lütfen 0 ve 100 arasında bir değer giriniz")
        continue
    vize_notları.append(vize_notu)
    final_notu=int(input(f"{Öğrenci_Ad_Soyad}'ın Final Notunu Giriniz: "))
    if final_notu>100 or final_notu<0:
         print("Lütfen 0 ve 100 arasında bir değer giriniz")
         continue
    final_notları.append(final_notu)
    def not_hesapla(vize_notu,final_notu):    
        genel_not=vize_notu*0.4+final_notu*0.6
        harf_notu_eşik=[(85,"AA"),(75,"BA"),(65,"BB"),(55,"CB"),(45,"CC"),(40,"DC"),(35,"DD"),(0,"FF")]
        for esik,harf in harf_notu_eşik:
            if genel_not>=esik:
                harf_notu=harf
                harf_notları.append(harf_notu)
                ortalama_notlar.append(genel_not)
                print(f"\n{Öğrenci_Numarası} - {Öğrenci_Ad_Soyad}\nOrtalaması: {genel_not} \nHarf Notu: {harf_notu}\n")
                break    
    not_hesapla(vize_notu,final_notu)
    i+=1



print("Harf Notu Yüzdelikleri: ")
harf_notları2=set(harf_notları)
for item in harf_notları2:
    result=harf_notları.count(item)
    print(f"{item} Harf Notları: %{(result*100/sınıf_mevcudu):.0f}")
print(f"\nGenel Ortalama: {sum(ortalama_notlar)/sınıf_mevcudu:.1f}\n")
# Out:
# 101 - Ali Şahin
# Ortalaması: 91.0
# Harf Notu: AA
#
#
# 102 - Esra Demir
# Ortalaması: 68.0
# Harf Notu: BB
#
#
# 103 - Rüya Hancı
# Ortalaması: 84.2
# Harf Notu: BA
#
#
# 104 - Hasan Aydın
# Ortalaması: 41.0
# Harf Notu: DC
#
#
# 105 - Yunus Yılmaz
# Ortalaması: 26.0
# Harf Notu: FF
#
#
# 106 - Sıla
# Ortalaması: 66.8
# Harf Notu: BB
#
#
# 107 - Murat Ayanoğlu
# Ortalaması: 53.0
# Harf Notu: CC
#
#
# 108 - Emre Koç
# Ortalaması: 69.0
# Harf Notu: BB
#
#
# 109 - Pelin Yakın
# Ortalaması: 61.0
# Harf Notu: CB
#
#
# 110 - Tarık
# Ortalaması: 38.0
# Harf Notu: DD
#
#
# 111 - Elif Aydınlı
# Ortalaması: 98.0
# Harf Notu: AA
#
#
# 112 - Ozan
# Ortalaması: 79.0
# Harf Notu: BA
#
#
# 113 - Mustafa
# Ortalaması: 83.0
# Harf Notu: BA
#
#
# 114 - Halit
# Ortalaması: 79.6
# Harf Notu: BA
#
#
# 115 - Zehra
# Ortalaması: 75.8
# Harf Notu: BA
#
#
# 116 - Kemal
# Ortalaması: 95.0
# Harf Notu: AA
#
#
# 117 - Leyla Durmaz
# Ortalaması: 91.6
# Harf Notu: AA
#
#
# 118 - Halime Sevinç
# ...
